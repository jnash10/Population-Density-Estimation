# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np
from scipy.signal import savgol_filter

# %%
df = pd.read_csv("log.csv").iloc[:5410]

# %%
fig = px.line(df,x='date',y='devices')
fig2 = px.scatter(df,x='date',y='devices',opacity=0.5)

# %%
x = df['date'][2400:5410]
y = df['devices'][2400:5410]

# %%
fig.show()

# %%
fig.write_html("pilog.html")

# %%
fig2.show()

# %%
fig2.write_html("scatter.html")

# %%
yhat = savgol_filter(df['devices'],301,6)

# %%
yhat
# Out:
# array([29.15590889, 27.45459187, 25.95881702, ..., -0.13279228,
#        -4.11458879, -8.26878641])

# %%
fig3=px.scatter(x=df['date'],y=yhat,opacity=0.5)

# %%
fig3.show()

# %%
fig3.write_html("smooth.html")
